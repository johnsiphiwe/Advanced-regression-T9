# %% [markdown]
# # Team 9

# %% [markdown]
# # Data manipulation and visualization libraries

# %%
# pandas for data manipulation
import pandas as pd

# %%
# matplotlib for data visualization
import matplotlib.pyplot as plt

# %%
# numpy for numerical analysis
import numpy as np

# %%
pip install -U seaborn
# Out:
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.1
#     Uninstalling seaborn-0.10.1:
#       Successfully uninstalled seaborn-0.10.1
# ...

# %%
# seaborn for data visualization and explain data analysis
import seaborn as sns

# %%
pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1320 sha256=57da6673af190177bf33a56a381709722522738cb6d65a22f1eba81532fe214d
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# loading the data
df = pd.read_csv("df_train.csv")

# %%
#check firts few rows
df.head(4)
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# 0                0.0                1.0  ...       265.938000      281.013000
# ...

# %%
#check last few rows
df.tail(4)
# Out:
#       Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 8759        8759  2017-12-31 12:00:00           5.000000           level_6
# 8760        8760  2017-12-31 15:00:00           6.333333           level_9
# 8761        8761  2017-12-31 18:00:00           7.333333           level_8
# 8762        8762  2017-12-31 21:00:00           4.333333           level_9
#
#       Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 8759             0.0             2.000000         82.000000        85.000000
# 8760             0.4             7.333333         67.666667        71.000000
# 8761             0.2             7.333333         67.666667        79.000000
# 8762             0.0             7.000000         78.666667        68.666667
#
#       Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  \
# 8759          26.666667           8.000000  ...       283.483333
# 8760          63.333333           8.333333  ...       285.150000
# ...

# %%
# get a concise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
# ...

# %% [markdown]
# # Data Engineering section

# %%
# remove missing values/features
df.dropna()
# Out:
#       Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0              0  2015-01-01 03:00:00           0.666667           level_5
# 1              1  2015-01-01 06:00:00           0.333333          level_10
# 2              2  2015-01-01 09:00:00           1.000000           level_9
# 3              3  2015-01-01 12:00:00           1.000000           level_8
# 6              6  2015-01-01 21:00:00           1.000000           level_8
# ...          ...                  ...                ...               ...
# 8745        8745  2017-12-29 18:00:00           4.333333           level_8
# 8750        8750  2017-12-30 09:00:00           4.000000           level_8
# 8759        8759  2017-12-31 12:00:00           5.000000           level_6
# 8760        8760  2017-12-31 15:00:00           6.333333           level_9
# 8761        8761  2017-12-31 18:00:00           7.333333           level_8
#
# ...

# %%
#drop the column Unnamed
df.drop("Unnamed: 0", inplace = True, axis = 'columns')

# %%
# engineer existing features

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# look at the  summary statistics of each variable
df.describe().T
# Out:
#                        count          mean           std          min  \
# Madrid_wind_speed     8763.0      2.425729      1.850371     0.000000
# Bilbao_rain_1h        8763.0      0.135753      0.374901     0.000000
# Valencia_wind_speed   8763.0      2.586272      2.411190     0.000000
# Seville_humidity      8763.0     62.658793     22.621226     8.333333
# Madrid_humidity       8763.0     57.414717     24.335396     6.333333
# Bilbao_clouds_all     8763.0     43.469132     32.551044     0.000000
# Bilbao_wind_speed     8763.0      1.850356      1.695888     0.000000
# Seville_clouds_all    8763.0     13.714748     24.272482     0.000000
# Bilbao_wind_deg       8763.0    158.957511    102.056299     0.000000
# Barcelona_wind_speed  8763.0      2.870497      1.792197     0.000000
# Barcelona_wind_deg    8763.0    190.544848     89.077337     0.000000
# Madrid_clouds_all     8763.0     19.473392     28.053660     0.000000
# ...

# %%
# look at the correlation of the data
corr = df.corr()
sns.heatmap(corr,annot = True)

# %%
# plot relevant feature interactions
sns.histplot(data = df)

# %%
# look at feature distributions
# Out:
# Unnamed: 0                             8762
# time                    2017-12-31 21:00:00
# Madrid_wind_speed                        13
# Valencia_wind_deg                   level_9
# Bilbao_rain_1h                            3
# Valencia_wind_speed                      52
# Seville_humidity                        100
# Madrid_humidity                         100
# Bilbao_clouds_all                       100
# Bilbao_wind_speed                   12.6667
# Seville_clouds_all                  97.3333
# Bilbao_wind_deg                     359.333
# Barcelona_wind_speed                12.6667
# Barcelona_wind_deg                      360
# Madrid_clouds_all                       100
# Seville_wind_speed                  11.6667
# Barcelona_rain_1h                        12
# Seville_pressure                        sp9
# Seville_rain_1h                           3
# Bilbao_snow_3h                         21.3
# Barcelona_pressure              1.00141e+06
# ...
